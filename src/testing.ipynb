# %%
import requests

# Define the API endpoint
url = 'https://globalcampus.ai/api/find_similar/'

# Define the request payload (parameters)
payload = {
  "search_module": 1,
  "limit": 5,
  "query_text": "Cancer and AI cure"
}
token = '67b1537b7e8f82c8e1af580f06e89a524efab8b7'


headers = {
    'Authorization': f'Token {token}',
    'Content-Type': 'application/json'
}

# Make a POST request to the API
response = requests.post(url, json=payload, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    # Do something with the data
    print(data)
else:
    # Print an error message if the request was unsuccessful
    print('Error:', response.status_code)
# Out:
# {'query_uuid': 'f2df79b7-78b8-418a-a9ed-fd1e78f3cf00', 'collection': {'records': [{'identifier': 'https://openalex.org/A5090973628', 'fields': {'relevance': 59.88398814336845, 'published_nl': 0, 'last_known_institution': {'id': 'I69552723', 'ror': 'https://ror.org/00g0p6g84', 'display_name': 'University of Pretoria', 'country_code': 'ZA', 'type': 'education', 'lineage': ['https://openalex.org/I69552723']}, 'institutions': [{'id': 'I69552723', 'country_code': 'ZA', 'type': 'education'}], 'last_published_institution': {'id': 'I69552723', 'display_name': 'University of Pretoria', 'ror': 'https://ror.org/00g0p6g84', 'country_code': 'ZA', 'type': 'education', 'lineage': ['https://openalex.org/I69552723']}, 'ranking_score': 855.7438102938952, 'id': 'https://openalex.org/A5090973628', 'orcid': 'https://orcid.org/0000-0002-8012-3646', 'display_name': 'Zodwa Dlamini', 'display_name_alternatives': ['Zodwa Dlamini', 'Zodwa Lawrentia. Dlamini', 'Zodwa L. Dlamini', 'Z. Dlamini'], 'works_count': 1
# ...

# %%
# Define the API endpoint
get_author_abstracts_url = 'https://globalcampus.ai/api/get_author_abstracts/'

# Define the request payload (parameters)
params = {
  "author_id": "A5037750063",
  "search_module": 1,
}

# Make a POST request to the API
response = requests.get(get_author_abstracts_url, params=params, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
    # Do something with the data
    print(data)
else:
    # Print an error message if the request was unsuccessful
    print('Error:', response.status_code)
# Out:
# {'meta': {'count': 1, 'db_response_time_ms': 31, 'page': 1, 'per_page': 8, 'groups_count': None}, 'results': [{'id': 'https://openalex.org/W4317609818', 'doi': 'https://doi.org/10.31234/osf.io/g93zf', 'title': 'Reproducibility and Data storage Checklist for Active Learning-Aided Systematic Reviews', 'display_name': 'Reproducibility and Data storage Checklist for Active Learning-Aided Systematic Reviews', 'publication_year': 2023, 'publication_date': '2023-01-19', 'ids': {'openalex': 'https://openalex.org/W4317609818', 'doi': 'https://doi.org/10.31234/osf.io/g93zf'}, 'language': 'en', 'primary_location': {'is_oa': True, 'landing_page_url': 'https://doi.org/10.31234/osf.io/g93zf', 'pdf_url': 'https://psyarxiv.com/g93zf/download', 'source': None, 'license': None, 'version': 'submittedVersion', 'is_accepted': False, 'is_published': False}, 'type': 'article', 'type_crossref': 'posted-content', 'indexed_in': ['crossref'], 'open_access': {'is_oa': True, 'oa_status': 'green', 'oa_url': 'http
# ...
